# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style('white')

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model, save_model
from keras.layers import Input, Dropout, BatchNormalization, Activation, Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers
import tensorflow as tf
from keras.preprocessing.image import array_to_img, img_to_array, load_img

import time
t_start = time.time()

# %%
version = 1
basic_name = f'Unet_resnet_v{version}'
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# Unet_resnet_v1.model
# Unet_resnet_v1.csv

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %%
train_df = pd.read_csv("../../data/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../../data/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

# %%
train_df["images"] = [np.array(load_img("../../data/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm(train_df.index)]
# Out:
# 100%|██████████| 4000/4000 [00:01<00:00, 2794.78it/s]

# %%
train_df["masks"] = [np.array(load_img("../../data/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm(train_df.index)]
# Out:
# 100%|██████████| 4000/4000 [00:01<00:00, 3360.01it/s]

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# Text(0.5,0,'Coverage class')

# %%
sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# Text(0.5,1,'Depth distribution')

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = \
train_test_split(train_df.index.values, 
                 np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1),
                 np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1),
                 train_df.coverage.values, 
                 train_df.z.values, 
                 test_size=0.2, stratify=train_df.coverage_class, random_state=555)

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation==True: x = BatchActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate=False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3))
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate: x = BatchActivate(x)
    return x

# %%
def build_model(input_layer, start_neurons, DropoutRatio=0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons*1, (3,3), activation=None, padding='same')(input_layer)
    conv1 = residual_block(conv1, start_neurons*1)
    conv1 = residual_block(conv1, start_neurons*1, True)
    pool1 = MaxPooling2D((2,2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)
    
    # 50 -> 25
    conv2 = Conv2D(start_neurons*2, (3,3), activation=None, padding='same')(pool1)
    conv2 = residual_block(conv2, start_neurons*2)
    conv2 = residual_block(conv2, start_neurons*2, True)
    pool2 = MaxPooling2D((2,2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)
    
    # 25 -> 12
    conv3 = Conv2D(start_neurons*4, (3,3), activation=None, padding='same')(pool2)
    conv3 = residual_block(conv3, start_neurons*4)
    conv3 = residual_block(conv3, start_neurons*4, True)
    pool3 = MaxPooling2D((2,2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)
    
    # 12 -> 6
    conv4 = Conv2D(start_neurons*8, (3,3), activation=None, padding='same')(pool3)
    conv4 = residual_block(conv4, start_neurons*8)
    conv4 = residual_block(conv4, start_neurons*8, True)
    pool4 = MaxPooling2D((2,2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)
    
    # Middle
    convm = Conv2D(start_neurons*16, (3,3), activation=None, padding='same')(pool4)
    convm = residual_block(convm, start_neurons*16)
    convm = residual_block(convm, start_neurons*16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons*8, (3,3), strides=(2,2), padding='same')(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons*8, (3,3), activation=None, padding='same')(uconv4)
    uconv4 = residual_block(uconv4, start_neurons*8)
    uconv4 = residual_block(uconv4, start_neurons*8, True)
    
    # 12 -> 25
    deconv3 = Conv2DTranspose(start_neurons*4, (3,3), strides=(2,2), padding='valid')(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons*4, (3,3), activation=None, padding='same')(uconv3)
    uconv3 = residual_block(uconv3, start_neurons*4)
    uconv3 = residual_block(uconv3, start_neurons*4, True)
    
    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons*2, (3,3), strides=(2,2), padding='same')(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    uconv2 = Dropout(DropoutRatio)(uconv2)
    
    uconv2 = Conv2D(start_neurons*2, (3,3), activation=None, padding='same')(uconv2)
    uconv2 = residual_block(uconv2, start_neurons*2)
    uconv2 = residual_block(uconv2, start_neurons*2, True)
    
    # 50 -> 101
    deconv1 = Conv2DTranspose(start_neurons*1, (3,3), strides=(2,2), padding='valid')(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    uconv1 = Dropout(DropoutRatio)(uconv1)
    
    uconv1 = Conv2D(start_neurons*1, (3,3), activation=None, padding='same')(uconv1)
    uconv1 = residual_block(uconv1, start_neurons*1)
    uconv1 = residual_block(uconv1, start_neurons*1, True)
    
    output_layer_noActi = Conv2D(1, (1,1), padding='same', activation=None)(uconv1)
    output_layer = Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))
        
    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard

# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss

def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.elu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16,0.5)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.005)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode = 'max',patience=15, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name, monitor='my_iou_metric', mode='max',
                                   save_best_only=True, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode='max', factor=0.5, patience=5,
                              min_lr=0.0001, verbose=1)

epochs = 100
batch_size = 128

t_model1_start = time.time()
history = model1.fit(x_train, y_train,
                     validation_data = [x_valid, y_valid], 
                     epochs = epochs, 
                     batch_size = batch_size, 
                     callbacks = [early_stopping, model_checkpoint, reduce_lr],
                     verbose = 2)
t_model1_end = time.time()
print(f"Run time = {(t_model1_end-t_model1_start)/3600} hours")
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/100
#  - 27s - loss: 0.4037 - my_iou_metric: 0.3200 - val_loss: 2.6307 - val_my_iou_metric: 0.2585
#
# Epoch 00001: my_iou_metric improved from -inf to 0.31998, saving model to Unet_resnet_v1.model
# Epoch 2/100
#  - 18s - loss: 0.2949 - my_iou_metric: 0.5310 - val_loss: 0.8852 - val_my_iou_metric: 0.0658
#
# Epoch 00002: my_iou_metric improved from 0.31998 to 0.53105, saving model to Unet_resnet_v1.model
# Epoch 3/100
#  - 18s - loss: 0.2640 - my_iou_metric: 0.5245 - val_loss: 0.5143 - val_my_iou_metric: 0.0401
#
# Epoch 00003: my_iou_metric did not improve from 0.53105
# Epoch 4/100
#  - 18s - loss: 0.2472 - my_iou_metric: 0.5541 - val_loss: 0.3884 - val_my_iou_metric: 0.2690
#
# Epoch 00004: my_iou_metric improved from 0.53105 to 0.55408, saving model to Unet_resnet_v1.model
# Epoch 5/100
#  - 18s - loss: 0.2358 - my_iou_metric: 0.5682 - val_loss: 0.5673 - val_my_iou_metric: 0.4575
#
# Epoch 00005: my_iou_metric improved from 0.55408 to 0.56817, saving model to Unet_resnet_v1.model
# Epoch 6/100
#  - 18s - loss: 0.2190 - my_iou_metric: 0.5746 - val_loss: 0.2488 - val_my_iou_metric: 0.4767
#
# Epoch 00006: my_iou_metric improved from 0.56817 to 0.57461, saving model to Unet_resnet_v1.model
# Epoch 7/100
#  - 18s - loss: 0.2121 - my_iou_metric: 0.5896 - val_loss: 0.2497 - val_my_iou_metric: 0.5562
#
# Epoch 00007: my_iou_metric improved from 0.57461 to 0.58958, saving model to Unet_resnet_v1.model
# Epoch 8/100
#  - 18s - loss: 0.2002 - my_iou_metric: 0.5995 - val_loss: 0.2966 - val_my_iou_metric: 0.5823
#
# Epoch 00008: my_iou_metric improved from 0.58958 to 0.59955, saving model to Unet_resnet_v1.model
# Epoch 9/100
#  - 18s - loss: 0.1999 - my_iou_metric: 0.6108 - val_loss: 0.2723 - val_my_iou_metric: 0.6208
#
# Epoch 00009: my_iou_metric improved from 0.59955 to 0.61083, saving model to Unet_resnet_v1.model
# Epoch 10/100
#  - 18s - loss: 0.1885 - my_iou_metric: 0.6258 - val_loss: 0.3520 - val_my_iou_metric: 0.6411
#
# Epoch 00010: my_iou_metric improved from 0.61083 to 0.62584, saving model to Unet_resnet_v1.model
# Epoch 11/100
#  - 18s - loss: 0.1870 - my_iou_metric: 0.6325 - val_loss: 0.3267 - val_my_iou_metric: 0.6133
#
# Epoch 00011: my_iou_metric improved from 0.62584 to 0.63245, saving model to Unet_resnet_v1.model
# Epoch 12/100
#  - 18s - loss: 0.1833 - my_iou_metric: 0.6222 - val_loss: 0.4778 - val_my_iou_metric: 0.4530
#
# Epoch 00012: my_iou_metric did not improve from 0.63245
# Epoch 13/100
#  - 18s - loss: 0.1763 - my_iou_metric: 0.6460 - val_loss: 0.3963 - val_my_iou_metric: 0.5655
#
# Epoch 00013: my_iou_metric improved from 0.63245 to 0.64600, saving model to Unet_resnet_v1.model
# Epoch 14/100
#  - 18s - loss: 0.1682 - my_iou_metric: 0.6591 - val_loss: 0.2058 - val_my_iou_metric: 0.5569
#
# Epoch 00014: my_iou_metric improved from 0.64600 to 0.65909, saving model to Unet_resnet_v1.model
# Epoch 15/100
#  - 18s - loss: 0.1634 - my_iou_metric: 0.6687 - val_loss: 0.2457 - val_my_iou_metric: 0.6519
#
# Epoch 00015: my_iou_metric improved from 0.65909 to 0.66872, saving model to Unet_resnet_v1.model
# Epoch 16/100
#  - 17s - loss: 0.1581 - my_iou_metric: 0.6681 - val_loss: 0.2655 - val_my_iou_metric: 0.5144
#
# Epoch 00016: my_iou_metric did not improve from 0.66872
# Epoch 17/100
#  - 18s - loss: 0.1497 - my_iou_metric: 0.6846 - val_loss: 0.3499 - val_my_iou_metric: 0.6344
#
# Epoch 00017: my_iou_metric improved from 0.66872 to 0.68464, saving model to Unet_resnet_v1.model
# Epoch 18/100
#  - 18s - loss: 0.1551 - my_iou_metric: 0.6799 - val_loss: 0.3385 - val_my_iou_metric: 0.5587
#
# Epoch 00018: my_iou_metric did not improve from 0.68464
# Epoch 19/100
#  - 18s - loss: 0.1530 - my_iou_metric: 0.6827 - val_loss: 0.5765 - val_my_iou_metric: 0.4905
#
# Epoch 00019: my_iou_metric did not improve from 0.68464
# Epoch 20/100
#  - 18s - loss: 0.1670 - my_iou_metric: 0.6626 - val_loss: 0.2136 - val_my_iou_metric: 0.5726
#
# Epoch 00020: my_iou_metric did not improve from 0.68464
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 21/100
#  - 18s - loss: 0.1376 - my_iou_metric: 0.7003 - val_loss: 0.1511 - val_my_iou_metric: 0.7226
#
# Epoch 00021: my_iou_metric improved from 0.68464 to 0.70031, saving model to Unet_resnet_v1.model
# Epoch 22/100
#  - 18s - loss: 0.1269 - my_iou_metric: 0.7165 - val_loss: 0.1325 - val_my_iou_metric: 0.7495
#
# Epoch 00022: my_iou_metric improved from 0.70031 to 0.71645, saving model to Unet_resnet_v1.model
# Epoch 23/100
#  - 18s - loss: 0.1243 - my_iou_metric: 0.7223 - val_loss: 0.1515 - val_my_iou_metric: 0.7239
#
# Epoch 00023: my_iou_metric improved from 0.71645 to 0.72231, saving model to Unet_resnet_v1.model
# Epoch 24/100
#  - 18s - loss: 0.1232 - my_iou_metric: 0.7276 - val_loss: 0.1371 - val_my_iou_metric: 0.7289
#
# Epoch 00024: my_iou_metric improved from 0.72231 to 0.72756, saving model to Unet_resnet_v1.model
# Epoch 25/100
#  - 18s - loss: 0.1163 - my_iou_metric: 0.7283 - val_loss: 0.1341 - val_my_iou_metric: 0.7208
#
# Epoch 00025: my_iou_metric improved from 0.72756 to 0.72827, saving model to Unet_resnet_v1.model
# Epoch 26/100
#  - 18s - loss: 0.1222 - my_iou_metric: 0.7274 - val_loss: 0.1349 - val_my_iou_metric: 0.7404
#
# Epoch 00026: my_iou_metric did not improve from 0.72827
# Epoch 27/100
#  - 18s - loss: 0.1156 - my_iou_metric: 0.7337 - val_loss: 0.1453 - val_my_iou_metric: 0.7512
#
# Epoch 00027: my_iou_metric improved from 0.72827 to 0.73370, saving model to Unet_resnet_v1.model
# Epoch 28/100
#  - 18s - loss: 0.1154 - my_iou_metric: 0.7345 - val_loss: 0.1262 - val_my_iou_metric: 0.7520
#
# Epoch 00028: my_iou_metric improved from 0.73370 to 0.73448, saving model to Unet_resnet_v1.model
# Epoch 29/100
#  - 18s - loss: 0.1165 - my_iou_metric: 0.7306 - val_loss: 0.1428 - val_my_iou_metric: 0.7216
#
# Epoch 00029: my_iou_metric did not improve from 0.73448
# Epoch 30/100
#  - 18s - loss: 0.1149 - my_iou_metric: 0.7291 - val_loss: 0.1495 - val_my_iou_metric: 0.7291
#
# Epoch 00030: my_iou_metric did not improve from 0.73448
# Epoch 31/100
#  - 18s - loss: 0.1143 - my_iou_metric: 0.7393 - val_loss: 0.1266 - val_my_iou_metric: 0.7446
#
# Epoch 00031: my_iou_metric improved from 0.73448 to 0.73930, saving model to Unet_resnet_v1.model
# Epoch 32/100
#  - 18s - loss: 0.1127 - my_iou_metric: 0.7387 - val_loss: 0.1410 - val_my_iou_metric: 0.6904
#
# Epoch 00032: my_iou_metric did not improve from 0.73930
# Epoch 33/100
#  - 18s - loss: 0.1028 - my_iou_metric: 0.7445 - val_loss: 0.1548 - val_my_iou_metric: 0.7455
#
# Epoch 00033: my_iou_metric improved from 0.73930 to 0.74455, saving model to Unet_resnet_v1.model
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 34/100
#  - 18s - loss: 0.0977 - my_iou_metric: 0.7563 - val_loss: 0.1227 - val_my_iou_metric: 0.7599
#
# Epoch 00034: my_iou_metric improved from 0.74455 to 0.75627, saving model to Unet_resnet_v1.model
# Epoch 35/100
#  - 18s - loss: 0.0914 - my_iou_metric: 0.7612 - val_loss: 0.1314 - val_my_iou_metric: 0.7646
#
# Epoch 00035: my_iou_metric improved from 0.75627 to 0.76119, saving model to Unet_resnet_v1.model
# Epoch 36/100
#  - 18s - loss: 0.0934 - my_iou_metric: 0.7577 - val_loss: 0.1204 - val_my_iou_metric: 0.7719
#
# Epoch 00036: my_iou_metric did not improve from 0.76119
# Epoch 37/100
#  - 18s - loss: 0.0894 - my_iou_metric: 0.7682 - val_loss: 0.1280 - val_my_iou_metric: 0.7834
#
# Epoch 00037: my_iou_metric improved from 0.76119 to 0.76820, saving model to Unet_resnet_v1.model
# Epoch 38/100
#  - 18s - loss: 0.0915 - my_iou_metric: 0.7628 - val_loss: 0.1328 - val_my_iou_metric: 0.7622
#
# Epoch 00038: my_iou_metric did not improve from 0.76820
# Epoch 39/100
#  - 18s - loss: 0.0884 - my_iou_metric: 0.7671 - val_loss: 0.1307 - val_my_iou_metric: 0.7641
#
# Epoch 00039: my_iou_metric did not improve from 0.76820
# Epoch 40/100
#  - 18s - loss: 0.0870 - my_iou_metric: 0.7673 - val_loss: 0.1216 - val_my_iou_metric: 0.7764
#
# Epoch 00040: my_iou_metric did not improve from 0.76820
# Epoch 41/100
#  - 18s - loss: 0.0880 - my_iou_metric: 0.7635 - val_loss: 0.1316 - val_my_iou_metric: 0.7794
#
# Epoch 00041: my_iou_metric did not improve from 0.76820
# Epoch 42/100
#  - 18s - loss: 0.0931 - my_iou_metric: 0.7648 - val_loss: 0.1290 - val_my_iou_metric: 0.7709
#
# Epoch 00042: my_iou_metric did not improve from 0.76820
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 43/100
#  - 18s - loss: 0.0806 - my_iou_metric: 0.7731 - val_loss: 0.1281 - val_my_iou_metric: 0.7871
#
# Epoch 00043: my_iou_metric improved from 0.76820 to 0.77309, saving model to Unet_resnet_v1.model
# Epoch 44/100
#  - 18s - loss: 0.0797 - my_iou_metric: 0.7743 - val_loss: 0.1294 - val_my_iou_metric: 0.7809
#
# Epoch 00044: my_iou_metric improved from 0.77309 to 0.77430, saving model to Unet_resnet_v1.model
# Epoch 45/100
#  - 18s - loss: 0.0787 - my_iou_metric: 0.7750 - val_loss: 0.1241 - val_my_iou_metric: 0.7834
#
# Epoch 00045: my_iou_metric improved from 0.77430 to 0.77497, saving model to Unet_resnet_v1.model
# Epoch 46/100
#  - 18s - loss: 0.0746 - my_iou_metric: 0.7825 - val_loss: 0.1254 - val_my_iou_metric: 0.7841
#
# Epoch 00046: my_iou_metric improved from 0.77497 to 0.78245, saving model to Unet_resnet_v1.model
# Epoch 47/100
#  - 18s - loss: 0.0740 - my_iou_metric: 0.7812 - val_loss: 0.1296 - val_my_iou_metric: 0.7748
#
# Epoch 00047: my_iou_metric did not improve from 0.78245
# Epoch 48/100
#  - 18s - loss: 0.0724 - my_iou_metric: 0.7782 - val_loss: 0.1285 - val_my_iou_metric: 0.7760
#
# Epoch 00048: my_iou_metric did not improve from 0.78245
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 49/100
#  - 18s - loss: 0.0710 - my_iou_metric: 0.7855 - val_loss: 0.1296 - val_my_iou_metric: 0.7767
#
# Epoch 00049: my_iou_metric improved from 0.78245 to 0.78550, saving model to Unet_resnet_v1.model
# Epoch 50/100
#  - 18s - loss: 0.0739 - my_iou_metric: 0.7848 - val_loss: 0.1305 - val_my_iou_metric: 0.7895
#
# Epoch 00050: my_iou_metric did not improve from 0.78550
# Epoch 51/100
#  - 18s - loss: 0.0689 - my_iou_metric: 0.7847 - val_loss: 0.1308 - val_my_iou_metric: 0.7792
#
# Epoch 00051: my_iou_metric did not improve from 0.78550
# Epoch 52/100
#  - 18s - loss: 0.0672 - my_iou_metric: 0.7918 - val_loss: 0.1316 - val_my_iou_metric: 0.7867
#
# Epoch 00052: my_iou_metric improved from 0.78550 to 0.79183, saving model to Unet_resnet_v1.model
# Epoch 53/100
#  - 18s - loss: 0.0672 - my_iou_metric: 0.7869 - val_loss: 0.1263 - val_my_iou_metric: 0.7836
#
# Epoch 00053: my_iou_metric did not improve from 0.79183
# Epoch 54/100
#  - 18s - loss: 0.0667 - my_iou_metric: 0.7893 - val_loss: 0.1367 - val_my_iou_metric: 0.7871
#
# Epoch 00054: my_iou_metric did not improve from 0.79183
# Epoch 55/100
#  - 18s - loss: 0.0698 - my_iou_metric: 0.7847 - val_loss: 0.1273 - val_my_iou_metric: 0.7867
#
# Epoch 00055: my_iou_metric did not improve from 0.79183
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 56/100
#  - 18s - loss: 0.0667 - my_iou_metric: 0.7908 - val_loss: 0.1292 - val_my_iou_metric: 0.7870
#
# Epoch 00056: my_iou_metric did not improve from 0.79183
# Epoch 57/100
#  - 18s - loss: 0.0664 - my_iou_metric: 0.7895 - val_loss: 0.1283 - val_my_iou_metric: 0.7836
#
# Epoch 00057: my_iou_metric did not improve from 0.79183
# Epoch 58/100
#  - 18s - loss: 0.0657 - my_iou_metric: 0.7917 - val_loss: 0.1264 - val_my_iou_metric: 0.7848
#
# Epoch 00058: my_iou_metric did not improve from 0.79183
# Epoch 59/100
#  - 18s - loss: 0.0666 - my_iou_metric: 0.7917 - val_loss: 0.1307 - val_my_iou_metric: 0.7845
#
# Epoch 00059: my_iou_metric did not improve from 0.79183
# Epoch 60/100
#  - 18s - loss: 0.0654 - my_iou_metric: 0.7923 - val_loss: 0.1278 - val_my_iou_metric: 0.7810
#
# Epoch 00060: my_iou_metric improved from 0.79183 to 0.79227, saving model to Unet_resnet_v1.model
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 61/100
#  - 18s - loss: 0.0635 - my_iou_metric: 0.7958 - val_loss: 0.1305 - val_my_iou_metric: 0.7835
#
# Epoch 00061: my_iou_metric improved from 0.79227 to 0.79575, saving model to Unet_resnet_v1.model
# Epoch 62/100
#  - 18s - loss: 0.0640 - my_iou_metric: 0.7968 - val_loss: 0.1293 - val_my_iou_metric: 0.7834
#
# Epoch 00062: my_iou_metric improved from 0.79575 to 0.79681, saving model to Unet_resnet_v1.model
# Epoch 63/100
#  - 18s - loss: 0.0652 - my_iou_metric: 0.7952 - val_loss: 0.1299 - val_my_iou_metric: 0.7828
#
# Epoch 00063: my_iou_metric did not improve from 0.79681
# Epoch 64/100
#  - 18s - loss: 0.0634 - my_iou_metric: 0.7908 - val_loss: 0.1337 - val_my_iou_metric: 0.7836
#
# Epoch 00064: my_iou_metric did not improve from 0.79681
# Epoch 65/100
#  - 18s - loss: 0.0643 - my_iou_metric: 0.7948 - val_loss: 0.1336 - val_my_iou_metric: 0.7854
#
# Epoch 00065: my_iou_metric did not improve from 0.79681
# Epoch 00065: early stopping
# Run time = 0.3283530298206541 hours

# %%
model1 = load_model(save_model_name, custom_objects={'my_iou_metric':my_iou_metric})
# remove activation layer and use lovasz loss
input_x = model1.layers[0].input

output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr=0.01)

model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=30, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, 
                              min_lr=0.00005, verbose=1)
epochs = 120
batch_size = 64

t_model2_start = time.time()
history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[ model_checkpoint,reduce_lr,early_stopping], 
                    verbose=2)
t_model2_end = time.time()
print(f"Run time = {(t_model2_end-t_model2_start)/3600} hours")
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/120
#  - 79s - loss: 0.3837 - my_iou_metric_2: 0.6759 - val_loss: 0.9049 - val_my_iou_metric_2: 0.5729
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.57287, saving model to Unet_resnet_v1.model
# Epoch 2/120
#  - 70s - loss: 0.3230 - my_iou_metric_2: 0.6892 - val_loss: 0.8785 - val_my_iou_metric_2: 0.5540
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.57287
# Epoch 3/120
#  - 69s - loss: 0.2621 - my_iou_metric_2: 0.7027 - val_loss: 0.6689 - val_my_iou_metric_2: 0.6269
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.57287 to 0.62687, saving model to Unet_resnet_v1.model
# Epoch 4/120
#  - 69s - loss: 0.2167 - my_iou_metric_2: 0.7167 - val_loss: 0.8825 - val_my_iou_metric_2: 0.5327
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.62687
# Epoch 5/120
#  - 70s - loss: 0.1803 - my_iou_metric_2: 0.7284 - val_loss: 0.1472 - val_my_iou_metric_2: 0.7334
#
# Epoch 00005: val_my_iou_metric_2 improved from 0.62687 to 0.73338, saving model to Unet_resnet_v1.model
# Epoch 6/120
#  - 71s - loss: 0.1576 - my_iou_metric_2: 0.7308 - val_loss: 0.2998 - val_my_iou_metric_2: 0.7016
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.73338
# Epoch 7/120
#  - 71s - loss: 0.2246 - my_iou_metric_2: 0.7150 - val_loss: 0.5768 - val_my_iou_metric_2: 0.6527
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.73338
# Epoch 8/120
#  - 71s - loss: 0.1515 - my_iou_metric_2: 0.7307 - val_loss: 0.4585 - val_my_iou_metric_2: 0.6600
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.73338
# Epoch 9/120
#  - 71s - loss: 0.0941 - my_iou_metric_2: 0.7430 - val_loss: 0.1645 - val_my_iou_metric_2: 0.7329
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.73338
# Epoch 10/120
#  - 71s - loss: 0.0951 - my_iou_metric_2: 0.7444 - val_loss: 1.3161 - val_my_iou_metric_2: 0.4609
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.73338
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 11/120
#  - 71s - loss: 0.0912 - my_iou_metric_2: 0.7484 - val_loss: 0.0702 - val_my_iou_metric_2: 0.7575
#
# Epoch 00011: val_my_iou_metric_2 improved from 0.73338 to 0.75750, saving model to Unet_resnet_v1.model
# Epoch 12/120
#  - 71s - loss: 0.0190 - my_iou_metric_2: 0.7636 - val_loss: 0.0345 - val_my_iou_metric_2: 0.7623
#
# Epoch 00012: val_my_iou_metric_2 improved from 0.75750 to 0.76225, saving model to Unet_resnet_v1.model
# Epoch 13/120
#  - 71s - loss: -2.9281e-02 - my_iou_metric_2: 0.7738 - val_loss: 0.1653 - val_my_iou_metric_2: 0.7436
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.76225
# Epoch 14/120
#  - 71s - loss: -5.5406e-02 - my_iou_metric_2: 0.7811 - val_loss: 0.2534 - val_my_iou_metric_2: 0.7206
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.76225
# Epoch 15/120
#  - 71s - loss: -6.8196e-02 - my_iou_metric_2: 0.7826 - val_loss: -1.0368e-01 - val_my_iou_metric_2: 0.8010
#
# Epoch 00015: val_my_iou_metric_2 improved from 0.76225 to 0.80100, saving model to Unet_resnet_v1.model
# Epoch 16/120
#  - 70s - loss: -8.1371e-02 - my_iou_metric_2: 0.7849 - val_loss: -8.4331e-02 - val_my_iou_metric_2: 0.7850
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.80100
# Epoch 17/120
#  - 72s - loss: -7.7464e-02 - my_iou_metric_2: 0.7829 - val_loss: 0.0481 - val_my_iou_metric_2: 0.7586
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.80100
# Epoch 18/120
#  - 68s - loss: -1.0168e-01 - my_iou_metric_2: 0.7868 - val_loss: 0.0050 - val_my_iou_metric_2: 0.7689
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.80100
# Epoch 19/120
#  - 71s - loss: -1.2379e-01 - my_iou_metric_2: 0.7938 - val_loss: -1.4388e-01 - val_my_iou_metric_2: 0.8004
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.80100
# Epoch 20/120
#  - 70s - loss: -1.4342e-01 - my_iou_metric_2: 0.7920 - val_loss: -3.2376e-02 - val_my_iou_metric_2: 0.7812
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.80100
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 21/120
#  - 71s - loss: -1.9856e-01 - my_iou_metric_2: 0.8089 - val_loss: -1.9988e-01 - val_my_iou_metric_2: 0.8125
#
# Epoch 00021: val_my_iou_metric_2 improved from 0.80100 to 0.81250, saving model to Unet_resnet_v1.model
# Epoch 22/120
#  - 70s - loss: -1.9718e-01 - my_iou_metric_2: 0.8068 - val_loss: -1.7679e-01 - val_my_iou_metric_2: 0.8086
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.81250
# Epoch 23/120
#  - 71s - loss: -1.8706e-01 - my_iou_metric_2: 0.8059 - val_loss: -1.4836e-01 - val_my_iou_metric_2: 0.8009
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.81250
# Epoch 24/120
#  - 71s - loss: -2.1561e-01 - my_iou_metric_2: 0.8126 - val_loss: -3.6506e-02 - val_my_iou_metric_2: 0.7769
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.81250
# Epoch 25/120
#  - 71s - loss: -2.1745e-01 - my_iou_metric_2: 0.8108 - val_loss: -1.4628e-01 - val_my_iou_metric_2: 0.8027
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.81250
# Epoch 26/120
#  - 71s - loss: -2.1435e-01 - my_iou_metric_2: 0.8106 - val_loss: -1.3226e-01 - val_my_iou_metric_2: 0.8031
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.81250
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 27/120
#  - 71s - loss: -2.5119e-01 - my_iou_metric_2: 0.8168 - val_loss: -2.1449e-01 - val_my_iou_metric_2: 0.8147
#
# Epoch 00027: val_my_iou_metric_2 improved from 0.81250 to 0.81475, saving model to Unet_resnet_v1.model
# Epoch 28/120
#  - 71s - loss: -2.5927e-01 - my_iou_metric_2: 0.8180 - val_loss: -2.1274e-01 - val_my_iou_metric_2: 0.8110
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.81475
# Epoch 29/120
#  - 71s - loss: -2.6983e-01 - my_iou_metric_2: 0.8207 - val_loss: -2.0970e-01 - val_my_iou_metric_2: 0.8154
#
# Epoch 00029: val_my_iou_metric_2 improved from 0.81475 to 0.81538, saving model to Unet_resnet_v1.model
# Epoch 30/120
#  - 71s - loss: -2.7127e-01 - my_iou_metric_2: 0.8213 - val_loss: -2.3236e-01 - val_my_iou_metric_2: 0.8136
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.81538
# Epoch 31/120
#  - 71s - loss: -2.8519e-01 - my_iou_metric_2: 0.8251 - val_loss: -2.3594e-01 - val_my_iou_metric_2: 0.8200
#
# Epoch 00031: val_my_iou_metric_2 improved from 0.81538 to 0.82000, saving model to Unet_resnet_v1.model
# Epoch 32/120
#  - 71s - loss: -2.7727e-01 - my_iou_metric_2: 0.8240 - val_loss: -2.0873e-01 - val_my_iou_metric_2: 0.8114
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 33/120
#  - 71s - loss: -2.9536e-01 - my_iou_metric_2: 0.8242 - val_loss: -2.1023e-01 - val_my_iou_metric_2: 0.8120
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 34/120
#  - 70s - loss: -2.9471e-01 - my_iou_metric_2: 0.8233 - val_loss: -2.2226e-01 - val_my_iou_metric_2: 0.8108
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 35/120
#  - 70s - loss: -3.0050e-01 - my_iou_metric_2: 0.8276 - val_loss: -2.4182e-01 - val_my_iou_metric_2: 0.8149
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 36/120
#  - 70s - loss: -2.9924e-01 - my_iou_metric_2: 0.8259 - val_loss: -2.3242e-01 - val_my_iou_metric_2: 0.8172
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.82000
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 37/120
#  - 70s - loss: -3.1898e-01 - my_iou_metric_2: 0.8296 - val_loss: -2.4519e-01 - val_my_iou_metric_2: 0.8150
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 38/120
#  - 71s - loss: -3.3706e-01 - my_iou_metric_2: 0.8347 - val_loss: -2.4151e-01 - val_my_iou_metric_2: 0.8172
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 39/120
#  - 70s - loss: -3.2470e-01 - my_iou_metric_2: 0.8314 - val_loss: -2.1291e-01 - val_my_iou_metric_2: 0.8151
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 40/120
#  - 70s - loss: -3.3345e-01 - my_iou_metric_2: 0.8338 - val_loss: -2.5046e-01 - val_my_iou_metric_2: 0.8161
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 41/120
#  - 71s - loss: -3.3536e-01 - my_iou_metric_2: 0.8312 - val_loss: -2.5391e-01 - val_my_iou_metric_2: 0.8176
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.82000
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 42/120
#  - 71s - loss: -3.4160e-01 - my_iou_metric_2: 0.8340 - val_loss: -2.5367e-01 - val_my_iou_metric_2: 0.8175
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 43/120
#  - 71s - loss: -3.4919e-01 - my_iou_metric_2: 0.8356 - val_loss: -2.5111e-01 - val_my_iou_metric_2: 0.8197
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.82000
# Epoch 44/120
#  - 71s - loss: -3.5038e-01 - my_iou_metric_2: 0.8353 - val_loss: -2.5909e-01 - val_my_iou_metric_2: 0.8209
#
# Epoch 00044: val_my_iou_metric_2 improved from 0.82000 to 0.82088, saving model to Unet_resnet_v1.model
# Epoch 45/120
#  - 71s - loss: -3.5720e-01 - my_iou_metric_2: 0.8362 - val_loss: -2.6127e-01 - val_my_iou_metric_2: 0.8229
#
# Epoch 00045: val_my_iou_metric_2 improved from 0.82088 to 0.82287, saving model to Unet_resnet_v1.model
# Epoch 46/120
#  - 71s - loss: -3.5022e-01 - my_iou_metric_2: 0.8360 - val_loss: -2.5649e-01 - val_my_iou_metric_2: 0.8199
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.82287
# Epoch 47/120
#  - 71s - loss: -3.5826e-01 - my_iou_metric_2: 0.8372 - val_loss: -2.5681e-01 - val_my_iou_metric_2: 0.8204
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.82287
# Epoch 48/120
#  - 71s - loss: -3.5842e-01 - my_iou_metric_2: 0.8372 - val_loss: -2.4722e-01 - val_my_iou_metric_2: 0.8156
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.82287
# Epoch 49/120
#  - 71s - loss: -3.5416e-01 - my_iou_metric_2: 0.8360 - val_loss: -2.6058e-01 - val_my_iou_metric_2: 0.8221
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.82287
# Epoch 50/120
#  - 70s - loss: -3.6326e-01 - my_iou_metric_2: 0.8381 - val_loss: -2.6418e-01 - val_my_iou_metric_2: 0.8236
#
# Epoch 00050: val_my_iou_metric_2 improved from 0.82287 to 0.82363, saving model to Unet_resnet_v1.model
# Epoch 51/120
#  - 71s - loss: -3.6844e-01 - my_iou_metric_2: 0.8393 - val_loss: -2.6561e-01 - val_my_iou_metric_2: 0.8237
#
# Epoch 00051: val_my_iou_metric_2 improved from 0.82363 to 0.82375, saving model to Unet_resnet_v1.model
# Epoch 52/120
#  - 71s - loss: -3.6101e-01 - my_iou_metric_2: 0.8383 - val_loss: -2.6928e-01 - val_my_iou_metric_2: 0.8236
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.82375
# Epoch 53/120
#  - 71s - loss: -3.5195e-01 - my_iou_metric_2: 0.8353 - val_loss: -2.7923e-01 - val_my_iou_metric_2: 0.8263
#
# Epoch 00053: val_my_iou_metric_2 improved from 0.82375 to 0.82625, saving model to Unet_resnet_v1.model
# Epoch 54/120
#  - 71s - loss: -3.6082e-01 - my_iou_metric_2: 0.8381 - val_loss: -2.7084e-01 - val_my_iou_metric_2: 0.8256
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 55/120
#  - 71s - loss: -3.7541e-01 - my_iou_metric_2: 0.8414 - val_loss: -2.5293e-01 - val_my_iou_metric_2: 0.8210
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 56/120
#  - 71s - loss: -3.6759e-01 - my_iou_metric_2: 0.8395 - val_loss: -2.6067e-01 - val_my_iou_metric_2: 0.8226
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 57/120
#  - 71s - loss: -3.7081e-01 - my_iou_metric_2: 0.8393 - val_loss: -2.4967e-01 - val_my_iou_metric_2: 0.8166
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 58/120
#  - 71s - loss: -3.7150e-01 - my_iou_metric_2: 0.8403 - val_loss: -2.4868e-01 - val_my_iou_metric_2: 0.8171
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.82625
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 59/120
#  - 71s - loss: -3.7431e-01 - my_iou_metric_2: 0.8398 - val_loss: -2.4728e-01 - val_my_iou_metric_2: 0.8207
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 60/120
#  - 71s - loss: -3.8092e-01 - my_iou_metric_2: 0.8432 - val_loss: -2.5635e-01 - val_my_iou_metric_2: 0.8213
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 61/120
#  - 71s - loss: -3.7842e-01 - my_iou_metric_2: 0.8407 - val_loss: -2.5831e-01 - val_my_iou_metric_2: 0.8200
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 62/120
#  - 71s - loss: -3.6983e-01 - my_iou_metric_2: 0.8390 - val_loss: -2.6621e-01 - val_my_iou_metric_2: 0.8215
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 63/120
#  - 71s - loss: -3.7450e-01 - my_iou_metric_2: 0.8398 - val_loss: -2.6705e-01 - val_my_iou_metric_2: 0.8214
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.82625
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 64/120
#  - 71s - loss: -3.8794e-01 - my_iou_metric_2: 0.8440 - val_loss: -2.6443e-01 - val_my_iou_metric_2: 0.8221
#
# Epoch 00064: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 65/120
#  - 71s - loss: -3.7506e-01 - my_iou_metric_2: 0.8399 - val_loss: -2.6073e-01 - val_my_iou_metric_2: 0.8235
#
# Epoch 00065: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 66/120
#  - 70s - loss: -3.8873e-01 - my_iou_metric_2: 0.8437 - val_loss: -2.6199e-01 - val_my_iou_metric_2: 0.8235
#
# Epoch 00066: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 67/120
#  - 71s - loss: -3.8073e-01 - my_iou_metric_2: 0.8423 - val_loss: -2.6099e-01 - val_my_iou_metric_2: 0.8250
#
# Epoch 00067: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 68/120
#  - 71s - loss: -3.9064e-01 - my_iou_metric_2: 0.8435 - val_loss: -2.6110e-01 - val_my_iou_metric_2: 0.8238
#
# Epoch 00068: val_my_iou_metric_2 did not improve from 0.82625
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 5e-05.
# Epoch 69/120
#  - 71s - loss: -3.8387e-01 - my_iou_metric_2: 0.8417 - val_loss: -2.5958e-01 - val_my_iou_metric_2: 0.8220
#
# Epoch 00069: val_my_iou_metric_2 did not improve from 0.82625
# Epoch 70/120
#  - 71s - loss: -3.8211e-01 - my_iou_metric_2: 0.8416 - val_loss: -2.6308e-01 - val_my_iou_metric_2: 0.8264
#
# Epoch 00070: val_my_iou_metric_2 improved from 0.82625 to 0.82638, saving model to Unet_resnet_v1.model
# Epoch 71/120
#  - 71s - loss: -3.8945e-01 - my_iou_metric_2: 0.8426 - val_loss: -2.6428e-01 - val_my_iou_metric_2: 0.8253
#
# Epoch 00071: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 72/120
#  - 71s - loss: -3.8517e-01 - my_iou_metric_2: 0.8440 - val_loss: -2.6296e-01 - val_my_iou_metric_2: 0.8248
#
# Epoch 00072: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 73/120
#  - 71s - loss: -3.8422e-01 - my_iou_metric_2: 0.8424 - val_loss: -2.6319e-01 - val_my_iou_metric_2: 0.8241
#
# Epoch 00073: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 74/120
#  - 71s - loss: -3.8781e-01 - my_iou_metric_2: 0.8430 - val_loss: -2.6275e-01 - val_my_iou_metric_2: 0.8239
#
# Epoch 00074: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 75/120
#  - 71s - loss: -3.8637e-01 - my_iou_metric_2: 0.8434 - val_loss: -2.6417e-01 - val_my_iou_metric_2: 0.8245
#
# Epoch 00075: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 76/120
#  - 71s - loss: -3.7640e-01 - my_iou_metric_2: 0.8444 - val_loss: -2.6376e-01 - val_my_iou_metric_2: 0.8241
#
# Epoch 00076: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 77/120
#  - 71s - loss: -3.8602e-01 - my_iou_metric_2: 0.8429 - val_loss: -2.6111e-01 - val_my_iou_metric_2: 0.8239
#
# Epoch 00077: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 78/120
#  - 71s - loss: -3.9010e-01 - my_iou_metric_2: 0.8428 - val_loss: -2.6260e-01 - val_my_iou_metric_2: 0.8257
#
# Epoch 00078: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 79/120
#  - 71s - loss: -3.8023e-01 - my_iou_metric_2: 0.8420 - val_loss: -2.6099e-01 - val_my_iou_metric_2: 0.8231
#
# Epoch 00079: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 80/120
#  - 71s - loss: -3.8517e-01 - my_iou_metric_2: 0.8419 - val_loss: -2.6370e-01 - val_my_iou_metric_2: 0.8252
#
# Epoch 00080: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 81/120
#  - 71s - loss: -3.8515e-01 - my_iou_metric_2: 0.8426 - val_loss: -2.6087e-01 - val_my_iou_metric_2: 0.8244
#
# Epoch 00081: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 82/120
#  - 71s - loss: -3.9404e-01 - my_iou_metric_2: 0.8445 - val_loss: -2.6176e-01 - val_my_iou_metric_2: 0.8234
#
# Epoch 00082: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 83/120
#  - 71s - loss: -3.9453e-01 - my_iou_metric_2: 0.8426 - val_loss: -2.5885e-01 - val_my_iou_metric_2: 0.8235
#
# Epoch 00083: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 84/120
#  - 71s - loss: -3.9470e-01 - my_iou_metric_2: 0.8444 - val_loss: -2.6124e-01 - val_my_iou_metric_2: 0.8247
#
# Epoch 00084: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 85/120
#  - 71s - loss: -3.8852e-01 - my_iou_metric_2: 0.8449 - val_loss: -2.5857e-01 - val_my_iou_metric_2: 0.8241
#
# Epoch 00085: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 86/120
#  - 71s - loss: -3.8441e-01 - my_iou_metric_2: 0.8422 - val_loss: -2.6237e-01 - val_my_iou_metric_2: 0.8234
#
# Epoch 00086: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 87/120
#  - 71s - loss: -3.9104e-01 - my_iou_metric_2: 0.8427 - val_loss: -2.6467e-01 - val_my_iou_metric_2: 0.8245
#
# Epoch 00087: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 88/120
#  - 71s - loss: -4.0028e-01 - my_iou_metric_2: 0.8463 - val_loss: -2.6292e-01 - val_my_iou_metric_2: 0.8255
#
# Epoch 00088: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 89/120
#  - 71s - loss: -3.8987e-01 - my_iou_metric_2: 0.8427 - val_loss: -2.6131e-01 - val_my_iou_metric_2: 0.8245
#
# Epoch 00089: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 90/120
#  - 71s - loss: -3.8081e-01 - my_iou_metric_2: 0.8408 - val_loss: -2.5970e-01 - val_my_iou_metric_2: 0.8226
#
# Epoch 00090: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 91/120
#  - 71s - loss: -3.8904e-01 - my_iou_metric_2: 0.8438 - val_loss: -2.6131e-01 - val_my_iou_metric_2: 0.8242
#
# Epoch 00091: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 92/120
#  - 71s - loss: -3.8674e-01 - my_iou_metric_2: 0.8429 - val_loss: -2.6292e-01 - val_my_iou_metric_2: 0.8248
#
# Epoch 00092: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 93/120
#  - 71s - loss: -3.9201e-01 - my_iou_metric_2: 0.8448 - val_loss: -2.6122e-01 - val_my_iou_metric_2: 0.8216
#
# Epoch 00093: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 94/120
#  - 71s - loss: -3.9052e-01 - my_iou_metric_2: 0.8428 - val_loss: -2.5893e-01 - val_my_iou_metric_2: 0.8219
#
# Epoch 00094: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 95/120
#  - 71s - loss: -3.8638e-01 - my_iou_metric_2: 0.8439 - val_loss: -2.5963e-01 - val_my_iou_metric_2: 0.8225
#
# Epoch 00095: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 96/120
#  - 71s - loss: -3.9460e-01 - my_iou_metric_2: 0.8466 - val_loss: -2.5926e-01 - val_my_iou_metric_2: 0.8240
#
# Epoch 00096: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 97/120
#  - 71s - loss: -3.9934e-01 - my_iou_metric_2: 0.8445 - val_loss: -2.5944e-01 - val_my_iou_metric_2: 0.8237
#
# Epoch 00097: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 98/120
#  - 71s - loss: -3.8966e-01 - my_iou_metric_2: 0.8435 - val_loss: -2.5905e-01 - val_my_iou_metric_2: 0.8235
#
# Epoch 00098: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 99/120
#  - 71s - loss: -3.9348e-01 - my_iou_metric_2: 0.8447 - val_loss: -2.5793e-01 - val_my_iou_metric_2: 0.8264
#
# Epoch 00099: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 100/120
#  - 71s - loss: -3.9455e-01 - my_iou_metric_2: 0.8424 - val_loss: -2.5501e-01 - val_my_iou_metric_2: 0.8220
#
# Epoch 00100: val_my_iou_metric_2 did not improve from 0.82638
# Epoch 00100: early stopping
# Run time = 1.9808174358473885 hours

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %%
preds_valid = predict_result(model,x_valid,img_size_target)

# %%
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in


    true_objects = 2
    pred_objects = 2

    #  if all zeros, original code  generate wrong  bins [-0.5 0 0.5],
    temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=([0,0.5,1], [0,0.5, 1]))
#     temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))
    #print(temp1)
    intersection = temp1[0]
    #print("temp2 = ",temp1[1])
    #print(intersection.shape)
   # print(intersection)
    # Compute areas (needed for finding the union between all objects)
    #print(np.histogram(labels, bins = true_objects))
    area_true = np.histogram(labels,bins=[0,0.5,1])[0]
    #print("area_true = ",area_true)
    area_pred = np.histogram(y_pred, bins=[0,0.5,1])[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection
  
    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    intersection[intersection == 0] = 1e-9
    
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union
    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
        
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# [0.81675  0.816375 0.817875 0.81875  0.818375 0.818875 0.81875  0.820125
#  0.820625 0.820375 0.82175  0.82125  0.823625 0.823375 0.82325  0.823
#  0.82325  0.823625 0.823875 0.82375  0.82375  0.823875 0.823875 0.825625
#  0.82525  0.825    0.824375 0.824375 0.823    0.8225   0.82175 ]

# %%
threshold_best_index = np.argmax(ious)
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, 'xr', label='Best threshold')
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
def rle_encode(im):
    '''
    im: numpy array, 1-mask, 0-background
    Returns run length as string
    '''
    pixels = im.flatten(order='F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
x_test = np.array([(np.array(load_img("../../data/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)
# Out:
#   0%|          | 0/18000 [00:00<?, ?it/s]
#   1%|          | 107/18000 [00:00<00:16, 1065.06it/s]
#   2%|▏         | 282/18000 [00:00<00:12, 1406.18it/s]
#   3%|▎         | 467/18000 [00:00<00:11, 1552.51it/s]
#   4%|▎         | 654/18000 [00:00<00:10, 1630.39it/s]
#   5%|▍         | 840/18000 [00:00<00:10, 1674.67it/s]
#   6%|▌         | 1028/18000 [00:00<00:09, 1708.07it/s]
#   7%|▋         | 1208/18000 [00:00<00:09, 1720.00it/s]
#   8%|▊         | 1395/18000 [00:00<00:09, 1738.62it/s]
#   9%|▉         | 1582/18000 [00:00<00:09, 1752.91it/s]
#  10%|▉         | 1769/18000 [00:01<00:09, 1764.13it/s]
#  11%|█         | 1952/18000 [00:01<00:09, 1769.51it/s]
#  12%|█▏        | 2134/18000 [00:01<00:08, 1773.33it/s]
#  13%|█▎        | 2315/18000 [00:01<00:08, 1774.52it/s]
#  14%|█▍        | 2498/18000 [00:01<00:08, 1778.33it/s]
#  15%|█▍        | 2682/18000 [00:01<00:08, 1781.78it/s]
#  16%|█▌        | 2864/18000 [00:01<00:08, 1781.99it/s]
#  17%|█▋        | 3046/18000 [00:01<00:08, 1784.19it/s]
#  18%|█▊        | 3229/18000 [00:01<00:08, 1786.16it/s]
#  19%|█▉        | 3411/18000 [00:01<00:08, 1787.68it/s]
#  20%|█▉        | 3593/18000 [00:02<00:08, 1788.78it/s]
#  21%|██        | 3776/18000 [00:02<00:07, 1790.76it/s]
#  22%|██▏       | 3959/18000 [00:02<00:07, 1792.52it/s]
#  23%|██▎       | 4142/18000 [00:02<00:07, 1790.58it/s]
#  24%|██▍       | 4326/18000 [00:02<00:07, 1792.34it/s]
#  25%|██▌       | 4509/18000 [00:02<00:07, 1793.62it/s]
#  26%|██▌       | 4691/18000 [00:02<00:07, 1794.33it/s]
#  27%|██▋       | 4873/18000 [00:02<00:07, 1794.70it/s]
#  28%|██▊       | 5055/18000 [00:02<00:07, 1795.14it/s]
#  29%|██▉       | 5236/18000 [00:02<00:07, 1793.38it/s]
#  30%|███       | 5422/18000 [00:03<00:07, 1795.28it/s]
#  31%|███       | 5603/18000 [00:03<00:06, 1794.21it/s]
#  32%|███▏      | 5783/18000 [00:03<00:06, 1794.30it/s]
#  33%|███▎      | 5963/18000 [00:03<00:06, 1793.89it/s]
#  34%|███▍      | 6143/18000 [00:03<00:06, 1793.88it/s]
#  35%|███▌      | 6327/18000 [00:03<00:06, 1795.08it/s]
#  36%|███▌      | 6512/18000 [00:03<00:06, 1796.46it/s]
#  37%|███▋      | 6695/18000 [00:03<00:06, 1797.17it/s]
#  38%|███▊      | 6877/18000 [00:03<00:06, 1797.44it/s]
#  39%|███▉      | 7059/18000 [00:03<00:06, 1798.00it/s]
#  40%|████      | 7241/18000 [00:04<00:05, 1798.11it/s]
#  41%|████      | 7423/18000 [00:04<00:05, 1798.48it/s]
#  42%|████▏     | 7607/18000 [00:04<00:05, 1799.39it/s]
#  43%|████▎     | 7789/18000 [00:04<00:05, 1799.85it/s]
#  44%|████▍     | 7971/18000 [00:04<00:05, 1799.88it/s]
#  45%|████▌     | 8153/18000 [00:04<00:05, 1799.67it/s]
#  46%|████▋     | 8334/18000 [00:04<00:05, 1799.28it/s]
#  47%|████▋     | 8514/18000 [00:04<00:05, 1799.25it/s]
#  48%|████▊     | 8694/18000 [00:04<00:05, 1797.64it/s]
#  49%|████▉     | 8876/18000 [00:04<00:05, 1797.95it/s]
#  50%|█████     | 9055/18000 [00:05<00:04, 1789.46it/s]
#  51%|█████▏    | 9235/18000 [00:05<00:04, 1789.60it/s]
#  52%|█████▏    | 9417/18000 [00:05<00:04, 1789.97it/s]
#  53%|█████▎    | 9596/18000 [00:05<00:04, 1789.86it/s]
#  54%|█████▍    | 9780/18000 [00:05<00:04, 1790.62it/s]
#  55%|█████▌    | 9967/18000 [00:05<00:04, 1791.85it/s]
#  56%|█████▋    | 10148/18000 [00:05<00:04, 1791.96it/s]
#  57%|█████▋    | 10329/18000 [00:05<00:04, 1790.97it/s]
#  58%|█████▊    | 10508/18000 [00:05<00:04, 1790.76it/s]
#  59%|█████▉    | 10689/18000 [00:05<00:04, 1790.95it/s]
#  60%|██████    | 10874/18000 [00:06<00:03, 1791.87it/s]
#  61%|██████▏   | 11055/18000 [00:06<00:03, 1791.78it/s]
#  62%|██████▏   | 11235/18000 [00:06<00:03, 1790.65it/s]
#  63%|██████▎   | 11413/18000 [00:06<00:03, 1789.11it/s]
#  64%|██████▍   | 11589/18000 [00:06<00:03, 1788.36it/s]
#  65%|██████▌   | 11769/18000 [00:06<00:03, 1788.47it/s]
#  66%|██████▋   | 11949/18000 [00:06<00:03, 1788.61it/s]
#  67%|██████▋   | 12131/18000 [00:06<00:03, 1788.93it/s]
#  68%|██████▊   | 12310/18000 [00:06<00:03, 1788.07it/s]
#  69%|██████▉   | 12487/18000 [00:06<00:03, 1786.67it/s]
#  70%|███████   | 12662/18000 [00:07<00:02, 1784.60it/s]
#  71%|███████▏  | 12843/18000 [00:07<00:02, 1784.87it/s]
#  72%|███████▏  | 13025/18000 [00:07<00:02, 1785.26it/s]
#  73%|███████▎  | 13207/18000 [00:07<00:02, 1785.72it/s]
#  74%|███████▍  | 13387/18000 [00:07<00:02, 1785.84it/s]
#  75%|███████▌  | 13567/18000 [00:07<00:02, 1785.94it/s]
#  76%|███████▋  | 13750/18000 [00:07<00:02, 1786.42it/s]
#  77%|███████▋  | 13930/18000 [00:07<00:02, 1786.47it/s]
#  78%|███████▊  | 14111/18000 [00:07<00:02, 1786.66it/s]
#  79%|███████▉  | 14291/18000 [00:07<00:02, 1786.60it/s]
#  80%|████████  | 14471/18000 [00:08<00:01, 1786.72it/s]
#  81%|████████▏ | 14651/18000 [00:08<00:01, 1786.69it/s]
#  82%|████████▏ | 14831/18000 [00:08<00:01, 1785.93it/s]
#  83%|████████▎ | 15009/18000 [00:08<00:01, 1785.28it/s]
#  84%|████████▍ | 15188/18000 [00:08<00:01, 1785.33it/s]
#  85%|████████▌ | 15368/18000 [00:08<00:01, 1785.47it/s]
#  86%|████████▋ | 15548/18000 [00:08<00:01, 1785.54it/s]
#  87%|████████▋ | 15727/18000 [00:08<00:01, 1785.40it/s]
#  88%|████████▊ | 15906/18000 [00:08<00:01, 1785.39it/s]
#  89%|████████▉ | 16085/18000 [00:09<00:01, 1785.14it/s]
#  90%|█████████ | 16265/18000 [00:09<00:00, 1785.26it/s]
#  91%|█████████▏| 16444/18000 [00:09<00:00, 1784.33it/s]
#  92%|█████████▏| 16620/18000 [00:09<00:00, 1782.29it/s]
#  93%|█████████▎| 16795/18000 [00:09<00:00, 1781.91it/s]
#  94%|█████████▍| 16978/18000 [00:09<00:00, 1782.35it/s]
#  95%|█████████▌| 17159/18000 [00:09<00:00, 1782.63it/s]
#  96%|█████████▋| 17337/18000 [00:09<00:00, 1781.97it/s]
#  97%|█████████▋| 17514/18000 [00:09<00:00, 1781.81it/s]
#  98%|█████████▊| 17690/18000 [00:09<00:00, 1781.17it/s]
#  99%|█████████▉| 17865/18000 [00:10<00:00, 1778.77it/s]
# 100%|██████████| 18000/18000 [00:10<00:00, 1777.43it/s]

# %%
preds_test = predict_result(model,x_test,img_size_target)

# %%
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm(test_df.index.values))}
# Out:
#   0%|          | 0/18000 [00:00<?, ?it/s]
#   3%|▎         | 473/18000 [00:00<00:03, 4708.64it/s]
#   6%|▌         | 1000/18000 [00:00<00:03, 4987.19it/s]
#   8%|▊         | 1521/18000 [00:00<00:03, 5060.08it/s]
#  11%|█▏        | 2045/18000 [00:00<00:03, 5104.29it/s]
#  14%|█▍        | 2555/18000 [00:00<00:03, 5102.98it/s]
#  17%|█▋        | 3043/18000 [00:00<00:02, 5065.39it/s]
#  20%|█▉        | 3556/18000 [00:00<00:02, 5074.20it/s]
#  23%|██▎       | 4072/18000 [00:00<00:02, 5084.22it/s]
#  25%|██▌       | 4577/18000 [00:00<00:02, 5080.35it/s]
#  28%|██▊       | 5103/18000 [00:01<00:02, 5098.26it/s]
#  31%|███       | 5624/18000 [00:01<00:02, 5108.20it/s]
#  34%|███▍      | 6146/18000 [00:01<00:02, 5117.37it/s]
#  37%|███▋      | 6667/18000 [00:01<00:02, 5123.47it/s]
#  40%|███▉      | 7186/18000 [00:01<00:02, 5127.72it/s]
#  43%|████▎     | 7701/18000 [00:01<00:02, 5120.44it/s]
#  46%|████▌     | 8212/18000 [00:01<00:01, 5113.19it/s]
#  48%|████▊     | 8720/18000 [00:01<00:01, 5100.25it/s]
#  51%|█████▏    | 9244/18000 [00:01<00:01, 5107.91it/s]
#  54%|█████▍    | 9753/18000 [00:01<00:01, 5104.21it/s]
#  57%|█████▋    | 10287/18000 [00:02<00:01, 5115.53it/s]
#  60%|██████    | 10813/18000 [00:02<00:01, 5121.91it/s]
#  63%|██████▎   | 11332/18000 [00:02<00:01, 5110.89it/s]
#  66%|██████▌   | 11854/18000 [00:02<00:01, 5115.20it/s]
#  69%|██████▉   | 12381/18000 [00:02<00:01, 5121.06it/s]
#  72%|███████▏  | 12905/18000 [00:02<00:00, 5125.56it/s]
#  75%|███████▍  | 13424/18000 [00:02<00:00, 5120.73it/s]
#  77%|███████▋  | 13938/18000 [00:02<00:00, 5106.63it/s]
#  80%|████████  | 14441/18000 [00:02<00:00, 5098.04it/s]
#  83%|████████▎ | 14944/18000 [00:02<00:00, 5095.70it/s]
#  86%|████████▌ | 15474/18000 [00:03<00:00, 5102.41it/s]
#  89%|████████▉ | 15995/18000 [00:03<00:00, 5105.63it/s]
#  92%|█████████▏| 16516/18000 [00:03<00:00, 5108.59it/s]
#  95%|█████████▍| 17031/18000 [00:03<00:00, 5107.28it/s]
#  97%|█████████▋| 17544/18000 [00:03<00:00, 5107.15it/s]
# 100%|██████████| 18000/18000 [00:03<00:00, 5103.84it/s]

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv(submission_file)
